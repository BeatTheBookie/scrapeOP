# %%
import os
from functions import *

print('Data will be saved in the following directory:', os.getcwd())

#scrape_oddsportal_historical(sport = 'soccer', country = 'france', league = 'ligue-1', start_season = '2010-2011', nseasons = 5, current_season = 'yes', max_page = 25)
scrape_oddsportal_current_season(sport = 'soccer', country = 'germany', league = 'bundesliga', season = '2023', max_page = 25)
#scrape_oddsportal_specific_season(sport = 'soccer', country = 'finland', league = 'veikkausliiga', season = '2019', max_page = 25)
#scrape_oddsportal_next_games(sport = 'tennis', country = 'germany', league = 'exhibition-bett1-aces-berlin-women', season = '2020')
# Out:
# Data will be saved in the following directory: c:\Users\andre\OneDrive\betting_db\005_notebooks\oddsportal\scrapeOP
# We start to scrape the page n°1
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-f3ffed137511> in <module>
#       5
#       6 #scrape_oddsportal_historical(sport = 'soccer', country = 'france', league = 'ligue-1', start_season = '2010-2011', nseasons = 5, current_season = 'yes', max_page = 25)
# ----> 7 scrape_oddsportal_current_season(sport = 'soccer', country = 'germany', league = 'bundesliga', season = '2023', max_page = 25)
#       8 #scrape_oddsportal_specific_season(sport = 'soccer', country = 'finland', league = 'veikkausliiga', season = '2019', max_page = 25)
#       9 #scrape_oddsportal_next_games(sport = 'tennis', country = 'germany', league = 'exhibition-bett1-aces-berlin-women', season = '2020')
#
# c:\Users\andre\OneDrive\betting_db\005_notebooks\oddsportal\scrapeOP\functions.py in scrape_oddsportal_current_season(sport, country, league, season, max_page)
#    1366     df = create_clean_table_two_ways(df)
#    1367   elif sport in ['soccer', 'rugby-union', 'rugby-league', 'handball']:
# -> 1368     df = scrape_current_season_typeC(tournament = league, sport = sport, country = country, SEASON = season, max_page = max_page)
#    1369     df = create_clean_table_three_ways(df)
#    1370   elif sport in ['hockey']:
#
# c:\Users\andre\OneDrive\betting_db\005_notebooks\oddsportal\scrapeOP\functions.py in scrape_current_season_typeC(tournament, sport, country, SEASON, max_page)
#     887
#     888         driver = webdriver.Chrome(executable_path=ChromeDriverManager().install())
# --> 889         data = scrape_page_current_season_typeC(page, sport, country, tournament)
#     890         DATA_ALL = DATA_ALL + [y for y in data if y != None]
#     891         driver.close()
#
# c:\Users\andre\OneDrive\betting_db\005_notebooks\oddsportal\scrapeOP\functions.py in scrape_page_current_season_typeC(page, sport, country, tournament)
#     810     DATA = []
#     811     for i in range(1,100):
# --> 812         content = get_data_typeC(i, link)
#     813         if content != None:
#     814             DATA = DATA + content
#
# c:\Users\andre\OneDrive\betting_db\005_notebooks\oddsportal\scrapeOP\functions.py in get_data_typeC(i, link)
#     698 def get_data_typeC(i, link):
#     699     driver.get(link)
# --> 700     reject_ads()
#     701     target = '//*[@id="tournamentTable"]/tbody/tr[{}]/td[2]/a'.format(i)
#     702     a = ffi2(target)
#
# c:\Users\andre\OneDrive\betting_db\005_notebooks\oddsportal\scrapeOP\functions.py in reject_ads(switch_to_decimal)
#    1493     if switch_to_decimal:
#    1494         # Change odds to decimal format
# -> 1495         driver.find_element("xpath", '//*[@id="user-header-oddsformat-expander"]').click()
#    1496         driver.find_element("xpath", '//*[@id="user-header-oddsformat"]/li[1]/a/span').click()
#
# c:\Users\andre\.conda\envs\Betting DB\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# c:\Users\andre\.conda\envs\Betting DB\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\Users\andre\.conda\envs\Betting DB\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="user-header-oddsformat-expander"]"}
#   (Session info: chrome=111.0.5563.147)
